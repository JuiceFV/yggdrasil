# %%
# fixes issue with editable package discovery on dbx
from site import addsitepackages

addsitepackages(None)

# %%
from yggdrasil.utils.dbx import setup_loggin_for_dbx_notebook

log = setup_loggin_for_dbx_notebook("dbx_train")

# %%
from hydra_zen import launch

from yggdrasil.train import ZENSTORE, RunCfg, register_config, run
# Out:
# INFO:yggdrasil.core.dataclasses:USE_VANILLA_DATACLASS: False
# INFO:yggdrasil.core.dataclasses:ARBITRARY_TYPES_ALLOWED: True
# INFO:datasets:PyTorch version 2.3.1 available.

# %%
register_config(RunCfg, ZENSTORE)

# %%
import os
default_overrides = (
    "experiment=mnist-mlp-multiclassification "
    "paths.log_dir=./logs "
)
overrides = default_overrides.split()

# %%
job = launch(RunCfg, run, version_base="1.3", overrides=list(overrides))
# Out:
# Seed set to 42
# [2025-06-17 21:02:28,599][yggdrasil.utils.boilerplate][INFO] - Enforcing tags! <cfg.enforce_tags=True>
# [2025-06-17 21:02:28,601][yggdrasil.utils.boilerplate][INFO] - Printing config tree with Rich! <cfg.print_config=True>
# CONFIG
# ├── datamodule
# │   └── _target_: yggdrasil.data.datamodules.mnist.MNISTDataModule
# │       _convert_: object
# │       input_table_spec:
# │         _target_: yggdrasil.core.dtypes.dataset.TableSpec
# │         _convert_: object
# │         table_identifier: mnist_784
# │         train_table_sample: 80.0
# │         eval_table_sample: 10.0
# │         test_table_sample: 10.0
# │       data_extractor:
# │         _target_: yggdrasil.data.data_extractor.mnist.MNISTDataExtractor
# │         _convert_: object
# │       setup_data: null
# │       saved_setup_data: null
# │       dataset_options:
# │         _target_: yggdrasil.core.dtypes.options.DatasetOptions
# │         _convert_: object
# │         minibatch_size: 1024
# │         num_proc: 1
# │         streaming: false
# │       features_preprocessing_options:
# │         _target_: yggdrasil.core.dtypes.preprocessing.options.PreprocessingOptions
# │         _convert_: object
# │         nsamples: 100
# │         max_unique_enum_values: 16
# │         quantile_size: 20
# │         quantile_k2_threshold: 1000.0
# │         skip_boxcox: false
# │         skip_quantiles: true
# │         feature_overrides: null
# │         table_sample: null
# │         set_missing_value_to_zero: false
# │         allowed_features: null
# │         assert_allowlist_feature_coverage: true
# │
# ├── model
# │   └── _target_: yggdrasil.modules.multi_classification.MultiClassificationModule
# │       _convert_: object
# │       net:
# │         _target_: yggdrasil.models.mlp.MultiClassificationMLPNetwork
# │         _convert_: object
# │         input_dim: 2008
# │         output_dim: 10
# │         hidden_dim: 512
# │         num_layers: 10
# │       optimizer:
# │         _target_: torch.optim.adam.Adam
# │         _partial_: true
# │         _convert_: object
# │         lr: 0.001
# │         betas:
# │         - 0.9
# │         - 0.999
# │         eps: 1.0e-08
# │         weight_decay: 0.0
# │         amsgrad: false
# │         foreach: null
# │         maximize: false
# │         capturable: false
# │         differentiable: false
# │         fused: null
# │       scheduler: null
# │       lr_scheduler_config: null
# │
# ├── callbacks
# │   └── summ_logger:
# │         _target_: yggdrasil.callbacks.logging.SummaryLogger
# │         _convert_: object
# │         max_depth: -1
# │       registry_hook:
# │         _target_: yggdrasil.callbacks.logging.MLFlowModelRegistryHook
# │         _convert_: object
# │       step_logging:
# │         _target_: yggdrasil.callbacks.logging.StepLoggingCallback
# │         _convert_: object
# │       timer:
# │         _target_: yggdrasil.callbacks.logging.TimingCallback
# │         _convert_: object
# │       lr_monitor:
# │         _target_: lightning.pytorch.callbacks.lr_monitor.LearningRateMonitor
# │         _convert_: object
# │         logging_interval: step
# │         log_momentum: true
# │         log_weight_decay: false
# │       best_ckpt:
# │         _target_: lightning.pytorch.callbacks.model_checkpoint.ModelCheckpoint
# │         _convert_: object
# │         dirpath: null
# │         filename: best_checkpoint
# │         monitor: val_loss_epoch
# │         verbose: true
# │         save_last: null
# │         save_top_k: 1
# │         save_weights_only: false
# │         mode: min
# │         auto_insert_metric_name: false
# │         every_n_train_steps: null
# │         train_time_interval: null
# │         every_n_epochs: null
# │         save_on_train_epoch_end: true
# │         enable_version_counter: true
# │       last_ckpt:
# │         _target_: lightning.pytorch.callbacks.model_checkpoint.ModelCheckpoint
# │         _convert_: object
# │         dirpath: null
# │         filename: last
# │         monitor: global_step
# │         verbose: true
# │         save_last: null
# │         save_top_k: 1
# │         save_weights_only: false
# │         mode: max
# │         auto_insert_metric_name: false
# │         every_n_train_steps: null
# │         train_time_interval: null
# │         every_n_epochs: null
# │         save_on_train_epoch_end: false
# │         enable_version_counter: true
# │       model_summ:
# │         _target_: lightning.pytorch.callbacks.rich_model_summary.RichModelSummary
# │         _convert_: object
# │         max_depth: -1
# │       richpb:
# │         _target_: lightning.pytorch.callbacks.progress.rich_progress.RichProgressBar
# │         _convert_: object
# │         refresh_rate: 1
# │         leave: false
# │         theme:
# │           _target_: lightning.pytorch.callbacks.progress.rich_progress.RichProgressBarTheme
# │           description: white
# │           progress_bar: '#6206E0'
# │           progress_bar_finished: '#6206E0'
# │           progress_bar_pulse: '#6206E0'
# │           batch_progress: white
# │           time: grey54
# │           processing_speed: grey70
# │           metrics: white
# │           metrics_text_delimiter: ' '
# │           metrics_format: .3f
# │         console_kwargs: null
# │       metrics:
# │         _target_: yggdrasil.callbacks.metrics.MetricCallback
# │         _convert_: object
# │         train_metrics:
# │           _target_: torchmetrics.collections.MetricCollection
# │           _convert_: object
# │           metrics:
# │           - _target_: torchmetrics.classification.accuracy.MulticlassAccuracy
# │             _convert_: object
# │             num_classes: 10
# │             top_k: 1
# │             average: macro
# │             multidim_average: global
# │             ignore_index: null
# │             validate_args: true
# │           - _target_: torchmetrics.classification.auroc.MulticlassAUROC
# │             _convert_: object
# │             num_classes: 10
# │             average: macro
# │             thresholds: null
# │             ignore_index: null
# │             validate_args: true
# │           - _target_: torchmetrics.classification.f_beta.MulticlassF1Score
# │             _convert_: object
# │             num_classes: 10
# │             top_k: 1
# │             average: macro
# │             multidim_average: global
# │             ignore_index: null
# │             validate_args: true
# │             zero_division: 0.0
# │           - _target_: torchmetrics.classification.calibration_error.MulticlassCalibrationError
# │             _convert_: object
# │             num_classes: 10
# │             n_bins: 15
# │             norm: l1
# │             ignore_index: null
# │             validate_args: true
# │           prefix: train_
# │           postfix: null
# │           compute_groups: true
# │         val_metrics: null
# │         test_metrics: null
# │       max_metrics:
# │         _target_: yggdrasil.callbacks.metrics.MaxMetricCallback
# │         _convert_: object
# │         metric_names:
# │         - val_MulticlassAccuracy
# │         - val_MulticlassAUROC
# │         - val_MulticlassF1Score
# │         - val_MulticlassCalibrationError
# │
# ├── loggers
# │   └── mlflow:
# │         _target_: yggdrasil.utils.mlflow.MLFlowLoggerCheckpointer
# │         _convert_: object
# │         experiment_name: /Shared/mnist-mlp-multiclassification
# │         run_name: null
# │         tracking_uri: file:./logs/mlflow/mlruns
# │         tags: null
# │         save_dir: ./mlruns
# │         prefix: ''
# │         artifact_location: null
# │         run_id: null
# │         custom_log_model: true
# │         register_model: true
# │         extra_files: null
# │         log_system_metrics: true
# │
# ├── trainer
# │   └── _target_: lightning.pytorch.trainer.trainer.Trainer
# │       _convert_: object
# │       callbacks:
# │       - _target_: yggdrasil.callbacks.logging.SummaryLogger
# │         _convert_: object
# │         max_depth: -1
# │       - _target_: yggdrasil.callbacks.logging.MLFlowModelRegistryHook
# │         _convert_: object
# │       - _target_: yggdrasil.callbacks.logging.StepLoggingCallback
# │         _convert_: object
# │       - _target_: yggdrasil.callbacks.logging.TimingCallback
# │         _convert_: object
# │       - _target_: lightning.pytorch.callbacks.lr_monitor.LearningRateMonitor
# │         _convert_: object
# │         logging_interval: step
# │         log_momentum: true
# │         log_weight_decay: false
# │       - _target_: lightning.pytorch.callbacks.model_checkpoint.ModelCheckpoint
# │         _convert_: object
# │         dirpath: null
# │         filename: best_checkpoint
# │         monitor: val_loss_epoch
# │         verbose: true
# │         save_last: null
# │         save_top_k: 1
# │         save_weights_only: false
# │         mode: min
# │         auto_insert_metric_name: false
# │         every_n_train_steps: null
# │         train_time_interval: null
# │         every_n_epochs: null
# │         save_on_train_epoch_end: true
# │         enable_version_counter: true
# │       - _target_: lightning.pytorch.callbacks.model_checkpoint.ModelCheckpoint
# │         _convert_: object
# │         dirpath: null
# │         filename: last
# │         monitor: global_step
# │         verbose: true
# │         save_last: null
# │         save_top_k: 1
# │         save_weights_only: false
# │         mode: max
# │         auto_insert_metric_name: false
# │         every_n_train_steps: null
# │         train_time_interval: null
# │         every_n_epochs: null
# │         save_on_train_epoch_end: false
# │         enable_version_counter: true
# │       - _target_: lightning.pytorch.callbacks.rich_model_summary.RichModelSummary
# │         _convert_: object
# │         max_depth: -1
# │       - _target_: lightning.pytorch.callbacks.progress.rich_progress.RichProgressBar
# │         _convert_: object
# │         refresh_rate: 1
# │         leave: false
# │         theme:
# │           _target_: lightning.pytorch.callbacks.progress.rich_progress.RichProgressBarTheme
# │           description: white
# │           progress_bar: '#6206E0'
# │           progress_bar_finished: '#6206E0'
# │           progress_bar_pulse: '#6206E0'
# │           batch_progress: white
# │           time: grey54
# │           processing_speed: grey70
# │           metrics: white
# │           metrics_text_delimiter: ' '
# │           metrics_format: .3f
# │         console_kwargs: null
# │       - _target_: yggdrasil.callbacks.metrics.MetricCallback
# │         _convert_: object
# │         train_metrics:
# │           _target_: torchmetrics.collections.MetricCollection
# │           _convert_: object
# │           metrics:
# │           - _target_: torchmetrics.classification.accuracy.MulticlassAccuracy
# │             _convert_: object
# │             num_classes: 10
# │             top_k: 1
# │             average: macro
# │             multidim_average: global
# │             ignore_index: null
# │             validate_args: true
# │           - _target_: torchmetrics.classification.auroc.MulticlassAUROC
# │             _convert_: object
# │             num_classes: 10
# │             average: macro
# │             thresholds: null
# │             ignore_index: null
# │             validate_args: true
# │           - _target_: torchmetrics.classification.f_beta.MulticlassF1Score
# │             _convert_: object
# │             num_classes: 10
# │             top_k: 1
# │             average: macro
# │             multidim_average: global
# │             ignore_index: null
# │             validate_args: true
# │             zero_division: 0.0
# │           - _target_: torchmetrics.classification.calibration_error.MulticlassCalibrationError
# │             _convert_: object
# │             num_classes: 10
# │             n_bins: 15
# │             norm: l1
# │             ignore_index: null
# │             validate_args: true
# │           prefix: train_
# │           postfix: null
# │           compute_groups: true
# │         val_metrics: null
# │         test_metrics: null
# │       - _target_: yggdrasil.callbacks.metrics.MaxMetricCallback
# │         _convert_: object
# │         metric_names:
# │         - val_MulticlassAccuracy
# │         - val_MulticlassAUROC
# │         - val_MulticlassF1Score
# │         - val_MulticlassCalibrationError
# │       logger:
# │       - _target_: yggdrasil.utils.mlflow.MLFlowLoggerCheckpointer
# │         _convert_: object
# │         experiment_name: /Shared/mnist-mlp-multiclassification
# │         run_name: null
# │         tracking_uri: file:./logs/mlflow/mlruns
# │         tags: null
# │         save_dir: ./mlruns
# │         prefix: ''
# │         artifact_location: null
# │         run_id: null
# │         custom_log_model: true
# │         register_model: true
# │         extra_files: null
# │         log_system_metrics: true
# │       default_root_dir: /Users/juicefv/project_template/notebooks/mnist/logs/train/runs/2025-06-17_21-02-28
# │       min_epochs: 1
# │       max_epochs: 30
# │       log_every_n_steps: 10
# │       accelerator: auto
# │       devices: 1
# │       check_val_every_n_epoch: 1
# │       enable_progress_bar: true
# │       deterministic: false
# │
# ├── paths
# │   └── log_dir: ./logs
# │       output_dir: /Users/juicefv/project_template/notebooks/mnist/logs/train/runs/2025-06-17_21-02-28
# │
# ├── task_name
# │   └── train
# ├── tags
# │   └── ['dev']
# ├── train
# │   └── True
# ├── test
# │   └── False
# ├── ckpt_path
# │   └── None
# ├── seed
# │   └── 42
# ├── ignore_warnings
# │   └── False
# ├── enforce_tags
# │   └── True
# ├── print_config
# │   └── True
# ├── _target_
# │   └── yggdrasil.main.main
# ├── _convert_
# │   └── object
# ├── optimized_metric
# │   └── None
# └── zen_cfg
#     └── None
# [2025-06-17 21:02:28,664][yggdrasil.utils.boilerplate][INFO] - Instantiating	main
# [2025-06-17 21:02:28,666][yggdrasil.utils.boilerplate][INFO] - Instantiating	TableSpec
# [2025-06-17 21:02:28,666][yggdrasil.utils.boilerplate][INFO] - Instantiating	MNISTDataExtractor
# [2025-06-17 21:02:28,667][yggdrasil.utils.boilerplate][INFO] - Instantiating	DatasetOptions
# [2025-06-17 21:02:28,667][yggdrasil.utils.boilerplate][INFO] - Instantiating	PreprocessingOptions
# [2025-06-17 21:02:28,667][yggdrasil.utils.boilerplate][INFO] - Instantiating	MNISTDataModule
# [2025-06-17 21:02:28,668][yggdrasil.utils.boilerplate][INFO] - Instantiating	MultiClassificationMLPNetwork
# [2025-06-17 21:02:28,683][yggdrasil.utils.boilerplate][INFO] - Instantiating	Adam
# [2025-06-17 21:02:28,684][yggdrasil.utils.boilerplate][INFO] - Instantiating	MultiClassificationModule
# [2025-06-17 21:02:28,689][yggdrasil.utils.boilerplate][INFO] - Instantiating	SummaryLogger
# [2025-06-17 21:02:28,690][yggdrasil.utils.boilerplate][INFO] - Instantiating	MLFlowModelRegistryHook
# [2025-06-17 21:02:28,690][yggdrasil.utils.boilerplate][INFO] - Instantiating	StepLoggingCallback
# [2025-06-17 21:02:28,690][yggdrasil.utils.boilerplate][INFO] - Instantiating	TimingCallback
# [2025-06-17 21:02:28,691][yggdrasil.utils.boilerplate][INFO] - Instantiating	LearningRateMonitor
# [2025-06-17 21:02:28,691][yggdrasil.utils.boilerplate][INFO] - Instantiating	ModelCheckpoint
# [2025-06-17 21:02:28,693][yggdrasil.utils.boilerplate][INFO] - Instantiating	ModelCheckpoint
# [2025-06-17 21:02:28,694][yggdrasil.utils.boilerplate][INFO] - Instantiating	RichModelSummary
# [2025-06-17 21:02:28,694][yggdrasil.utils.boilerplate][INFO] - Instantiating	RichProgressBarTheme
# [2025-06-17 21:02:28,695][yggdrasil.utils.boilerplate][INFO] - Instantiating	RichProgressBar
# [2025-06-17 21:02:28,696][yggdrasil.utils.boilerplate][INFO] - Instantiating	MulticlassAccuracy
# [2025-06-17 21:02:28,699][yggdrasil.utils.boilerplate][INFO] - Instantiating	MulticlassAUROC
# [2025-06-17 21:02:28,700][yggdrasil.utils.boilerplate][INFO] - Instantiating	MulticlassF1Score
# [2025-06-17 21:02:28,701][yggdrasil.utils.boilerplate][INFO] - Instantiating	MulticlassCalibrationError
# [2025-06-17 21:02:28,701][yggdrasil.utils.boilerplate][INFO] - Instantiating	MetricCollection
# [2025-06-17 21:02:28,702][yggdrasil.utils.boilerplate][INFO] - Instantiating	MetricCallback
# [2025-06-17 21:02:28,706][yggdrasil.utils.boilerplate][INFO] - Instantiating	MaxMetricCallback
# [2025-06-17 21:02:28,707][yggdrasil.utils.boilerplate][INFO] - Instantiating	MLFlowLoggerCheckpointer
# [2025-06-17 21:02:28,711][yggdrasil.utils.boilerplate][INFO] - Instantiating	Trainer
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [2025-06-17 21:02:28,761][yggdrasil.utils.boilerplate][INFO] - Logging hyperparameters!
# Experiment with name /Shared/mnist-mlp-multiclassification not found. Creating it.
# 2025/06/17 21:02:28 WARNING mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics because creating `GPUMonitor` failed with error: Failed to initialize NVML, skip logging GPU metrics: NVML Shared Library Not Found.
# 2025/06/17 21:02:28 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# [2025-06-17 21:02:28,915][yggdrasil.main][INFO] - Starting training!
# 25/06/17 21:02:29 WARN Utils: Your hostname, MacBook-Pro-Kasan.local resolves to a loopback address: 127.0.0.1; using 192.168.1.18 instead (on interface en0)
# 25/06/17 21:02:29 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/17 21:02:29 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# [Stage 18:==============================================>           (4 + 1) / 5]
# [2025-06-17 21:02:56,593][yggdrasil.preprocessing.normalization][INFO] - Extracting normalization for feature: 0
# [2025-06-17 21:02:56,594][yggdrasil.preprocessing.normalization][INFO] - Feature 0 normalization NormalizationParams(ftype=<Ftype.BINARY: 'binary'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0, max_value=0.0)
# [2025-06-17 21:02:56,594][yggdrasil.preprocessing.normalization][INFO] - Extracting normalization for feature: 1
# [2025-06-17 21:02:56,595][yggdrasil.preprocessing.normalization][INFO] - Feature 1 normalization NormalizationParams(ftype=<Ftype.BINARY: 'binary'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0, max_value=0.0)
# [2025-06-17 21:02:56,595][yggdrasil.preprocessing.normalization][INFO] - Extracting normalization for feature: 2
# ...
# [2025-06-17 21:06:50,806][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 21, global step 1210: 'val_loss_epoch' was not in top 1
# [2025-06-17 21:06:55,572][yggdrasil.modules.base][INFO] - Finished validation epoch 22 with 7 batches processed
# [2025-06-17 21:06:55,580][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 22, global step 1265: 'global_step' reached 1265.00000 (best 1265.00000), saving model to './logs/mlflow/mlruns/907293286074456611/b95820f3d16244569c03cffea5733fa8/checkpoints/last.ckpt' as top 1
# 2025/06/17 21:06:58 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be
# added to conda.yaml environment spec without a version specifier.
# Epoch 22/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:03 • 0:00:00 14.46it/s v_num: 3fa8 train_loss_step: 0.014
#                                                                                  val_loss_step: 0.137
#                                                                                  val_loss_epoch: 0.163
#                                                                                  train_loss_epoch: 0.011
# 2025/06/17 21:06:58 WARNING mlflow.models.model: Model logged without a signature and input example. Please set
# `input_example` parameter when logging the model to auto infer the model signature.
# Epoch 22/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:03 • 0:00:00 14.46it/s v_num: 3fa8 train_loss_step: 0.014
#                                                                                  val_loss_step: 0.137
#                                                                                  val_loss_epoch: 0.163
#                                                                                  train_loss_epoch: 0.011
# [2025-06-17 21:06:59,131][yggdrasil.modules.base][INFO] - Finished train epoch 22 with 55 batches processed
# [2025-06-17 21:06:59,469][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 22, global step 1265: 'val_loss_epoch' was not in top 1
# [2025-06-17 21:07:04,251][yggdrasil.modules.base][INFO] - Finished validation epoch 23 with 7 batches processed
# [2025-06-17 21:07:04,260][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 23, global step 1320: 'global_step' reached 1320.00000 (best 1320.00000), saving model to './logs/mlflow/mlruns/907293286074456611/b95820f3d16244569c03cffea5733fa8/checkpoints/last.ckpt' as top 1
# 2025/06/17 21:07:07 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be
# added to conda.yaml environment spec without a version specifier.
# Epoch 23/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:03 • 0:00:00 14.62it/s v_num: 3fa8 train_loss_step: 0.006
#                                                                                  val_loss_step: 0.154
#                                                                                  val_loss_epoch: 0.173
#                                                                                  train_loss_epoch: 0.015
# 2025/06/17 21:07:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set
# `input_example` parameter when logging the model to auto infer the model signature.
# Epoch 23/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:03 • 0:00:00 14.62it/s v_num: 3fa8 train_loss_step: 0.006
#                                                                                  val_loss_step: 0.154
#                                                                                  val_loss_epoch: 0.173
#                                                                                  train_loss_epoch: 0.015
# [2025-06-17 21:07:08,198][yggdrasil.modules.base][INFO] - Finished train epoch 23 with 55 batches processed
# [2025-06-17 21:07:08,442][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 23, global step 1320: 'val_loss_epoch' was not in top 1
# [2025-06-17 21:07:13,831][yggdrasil.modules.base][INFO] - Finished validation epoch 24 with 7 batches processed
# [2025-06-17 21:07:13,839][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 24, global step 1375: 'global_step' reached 1375.00000 (best 1375.00000), saving model to './logs/mlflow/mlruns/907293286074456611/b95820f3d16244569c03cffea5733fa8/checkpoints/last.ckpt' as top 1
# 2025/06/17 21:07:16 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be
# added to conda.yaml environment spec without a version specifier.
# Epoch 24/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:04 • 0:00:00 13.20it/s v_num: 3fa8 train_loss_step: 0.007
#                                                                                  val_loss_step: 0.150
#                                                                                  val_loss_epoch: 0.158
#                                                                                  train_loss_epoch: 0.015
# 2025/06/17 21:07:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set
# `input_example` parameter when logging the model to auto infer the model signature.
# Epoch 24/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:04 • 0:00:00 13.20it/s v_num: 3fa8 train_loss_step: 0.007
#                                                                                  val_loss_step: 0.150
#                                                                                  val_loss_epoch: 0.158
#                                                                                  train_loss_epoch: 0.015
# [2025-06-17 21:07:17,770][yggdrasil.modules.base][INFO] - Finished train epoch 24 with 55 batches processed
# [2025-06-17 21:07:18,054][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 24, global step 1375: 'val_loss_epoch' was not in top 1
# [2025-06-17 21:07:23,396][yggdrasil.modules.base][INFO] - Finished validation epoch 25 with 7 batches processed
# [2025-06-17 21:07:23,406][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 25, global step 1430: 'global_step' reached 1430.00000 (best 1430.00000), saving model to './logs/mlflow/mlruns/907293286074456611/b95820f3d16244569c03cffea5733fa8/checkpoints/last.ckpt' as top 1
# 2025/06/17 21:07:26 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be
# added to conda.yaml environment spec without a version specifier.
# Epoch 25/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:03 • 0:00:00 14.14it/s v_num: 3fa8 train_loss_step: 0.017
#                                                                                  val_loss_step: 0.093
#                                                                                  val_loss_epoch: 0.138
#                                                                                  train_loss_epoch: 0.012
# 2025/06/17 21:07:26 WARNING mlflow.models.model: Model logged without a signature and input example. Please set
# `input_example` parameter when logging the model to auto infer the model signature.
# Epoch 25/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:03 • 0:00:00 14.14it/s v_num: 3fa8 train_loss_step: 0.017
#                                                                                  val_loss_step: 0.093
#                                                                                  val_loss_epoch: 0.138
#                                                                                  train_loss_epoch: 0.012
# [2025-06-17 21:07:27,639][yggdrasil.modules.base][INFO] - Finished train epoch 25 with 55 batches processed
# [2025-06-17 21:07:28,001][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 25, global step 1430: 'val_loss_epoch' was not in top 1
# [2025-06-17 21:07:33,012][yggdrasil.modules.base][INFO] - Finished validation epoch 26 with 7 batches processed
# [2025-06-17 21:07:33,020][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 26, global step 1485: 'global_step' reached 1485.00000 (best 1485.00000), saving model to './logs/mlflow/mlruns/907293286074456611/b95820f3d16244569c03cffea5733fa8/checkpoints/last.ckpt' as top 1
# 2025/06/17 21:07:36 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be
# added to conda.yaml environment spec without a version specifier.
# Epoch 26/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:03 • 0:00:00 14.18it/s v_num: 3fa8 train_loss_step: 0.003
#                                                                                  val_loss_step: 0.173
#                                                                                  val_loss_epoch: 0.164
#                                                                                  train_loss_epoch: 0.011
# 2025/06/17 21:07:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set
# `input_example` parameter when logging the model to auto infer the model signature.
# Epoch 26/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:03 • 0:00:00 14.18it/s v_num: 3fa8 train_loss_step: 0.003
#                                                                                  val_loss_step: 0.173
#                                                                                  val_loss_epoch: 0.164
#                                                                                  train_loss_epoch: 0.011
# [2025-06-17 21:07:37,898][yggdrasil.modules.base][INFO] - Finished train epoch 26 with 55 batches processed
# [2025-06-17 21:07:38,099][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 26, global step 1485: 'val_loss_epoch' was not in top 1
# [2025-06-17 21:07:43,710][yggdrasil.modules.base][INFO] - Finished validation epoch 27 with 7 batches processed
# [2025-06-17 21:07:43,718][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 27, global step 1540: 'global_step' reached 1540.00000 (best 1540.00000), saving model to './logs/mlflow/mlruns/907293286074456611/b95820f3d16244569c03cffea5733fa8/checkpoints/last.ckpt' as top 1
# 2025/06/17 21:07:46 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be
# added to conda.yaml environment spec without a version specifier.
# Epoch 27/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:04 • 0:00:00 13.13it/s v_num: 3fa8 train_loss_step: 0.006
#                                                                                  val_loss_step: 0.194
#                                                                                  val_loss_epoch: 0.180
#                                                                                  train_loss_epoch: 0.014
# 2025/06/17 21:07:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set
# `input_example` parameter when logging the model to auto infer the model signature.
# Epoch 27/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:04 • 0:00:00 13.13it/s v_num: 3fa8 train_loss_step: 0.006
#                                                                                  val_loss_step: 0.194
#                                                                                  val_loss_epoch: 0.180
#                                                                                  train_loss_epoch: 0.014
# [2025-06-17 21:07:48,020][yggdrasil.modules.base][INFO] - Finished train epoch 27 with 55 batches processed
# [2025-06-17 21:07:48,231][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 27, global step 1540: 'val_loss_epoch' was not in top 1
# [2025-06-17 21:07:53,613][yggdrasil.modules.base][INFO] - Finished validation epoch 28 with 7 batches processed
# [2025-06-17 21:07:53,621][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 28, global step 1595: 'global_step' reached 1595.00000 (best 1595.00000), saving model to './logs/mlflow/mlruns/907293286074456611/b95820f3d16244569c03cffea5733fa8/checkpoints/last.ckpt' as top 1
# 2025/06/17 21:07:56 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be
# added to conda.yaml environment spec without a version specifier.
# Epoch 28/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:03 • 0:00:00 14.04it/s v_num: 3fa8 train_loss_step: 0.002
#                                                                                  val_loss_step: 0.135
#                                                                                  val_loss_epoch: 0.162
#                                                                                  train_loss_epoch: 0.012
# 2025/06/17 21:07:56 WARNING mlflow.models.model: Model logged without a signature and input example. Please set
# `input_example` parameter when logging the model to auto infer the model signature.
# Epoch 28/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:03 • 0:00:00 14.04it/s v_num: 3fa8 train_loss_step: 0.002
#                                                                                  val_loss_step: 0.135
#                                                                                  val_loss_epoch: 0.162
#                                                                                  train_loss_epoch: 0.012
# [2025-06-17 21:07:57,883][yggdrasil.modules.base][INFO] - Finished train epoch 28 with 55 batches processed
# [2025-06-17 21:07:58,091][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 28, global step 1595: 'val_loss_epoch' was not in top 1
# [2025-06-17 21:08:03,486][yggdrasil.modules.base][INFO] - Finished validation epoch 29 with 7 batches processed
# [2025-06-17 21:08:03,493][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 29, global step 1650: 'global_step' reached 1650.00000 (best 1650.00000), saving model to './logs/mlflow/mlruns/907293286074456611/b95820f3d16244569c03cffea5733fa8/checkpoints/last.ckpt' as top 1
# 2025/06/17 21:08:06 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be
# added to conda.yaml environment spec without a version specifier.
# Epoch 29/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:04 • 0:00:00 13.02it/s v_num: 3fa8 train_loss_step: 0.009
#                                                                                  val_loss_step: 0.172
#                                                                                  val_loss_epoch: 0.190
#                                                                                  train_loss_epoch: 0.011
# 2025/06/17 21:08:06 WARNING mlflow.models.model: Model logged without a signature and input example. Please set
# `input_example` parameter when logging the model to auto infer the model signature.
# Epoch 29/29 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55/55 0:00:04 • 0:00:00 13.02it/s v_num: 3fa8 train_loss_step: 0.009
#                                                                                  val_loss_step: 0.172
#                                                                                  val_loss_epoch: 0.190
#                                                                                  train_loss_epoch: 0.011
# [2025-06-17 21:08:07,550][yggdrasil.modules.base][INFO] - Finished train epoch 29 with 55 batches processed
# [2025-06-17 21:08:07,803][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 29, global step 1650: 'val_loss_epoch' was not in top 1
# [2025-06-17 21:08:07,813][pytorch_lightning.utilities.rank_zero][INFO] - `Trainer.fit` stopped: `max_epochs=30` reached.
# 2025/06/17 21:08:07 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/06/17 21:08:07 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [2025-06-17 21:08:07,900][yggdrasil.utils.boilerplate][INFO] - Output dir: /Users/juicefv/project_template/notebooks/mnist/logs/train/runs/2025-06-17_21-02-28

# %%
import subprocess

assert job.cfg is not None, "Log directory must be specified in the configuration."

mlflow_dir = job.cfg["paths"]["log_dir"] + "/mlflow/mlruns"
print(f"MLflow runs are stored in: {mlflow_dir}")

try:
    subprocess.run(["mlflow", "ui", "--backend-store-uri", f"file:{mlflow_dir}"])
except KeyboardInterrupt:
    print("MLflow UI stopped by user.")
# Out:
# MLflow runs are stored in: ./logs/mlflow/mlruns
# [2025-06-17 21:08:08 +0400] [74730] [INFO] Starting gunicorn 23.0.0
# [2025-06-17 21:08:08 +0400] [74730] [INFO] Listening at: http://127.0.0.1:5000 (74730)
# [2025-06-17 21:08:08 +0400] [74730] [INFO] Using worker: sync
# [2025-06-17 21:08:08 +0400] [74731] [INFO] Booting worker with pid: 74731
# [2025-06-17 21:08:08 +0400] [74732] [INFO] Booting worker with pid: 74732
# [2025-06-17 21:08:08 +0400] [74733] [INFO] Booting worker with pid: 74733
# [2025-06-17 21:08:08 +0400] [74734] [INFO] Booting worker with pid: 74734
# [2025-06-17 21:16:58 +0400] [74730] [INFO] Handling signal: int
# [2025-06-17 21:16:59 +0400] [74732] [INFO] Worker exiting (pid: 74732)
# [2025-06-17 21:16:59 +0400] [74731] [INFO] Worker exiting (pid: 74731)
# [2025-06-17 21:16:59 +0400] [74733] [INFO] Worker exiting (pid: 74733)
# [2025-06-17 21:16:59 +0400] [74734] [INFO] Worker exiting (pid: 74734)
# MLflow UI stopped by user.
# Aborted!
# [2025-06-17 21:16:59 +0400] [74730] [INFO] Shutting down: Master
