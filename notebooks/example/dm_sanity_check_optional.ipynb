# %%
# %load_ext autoreload
# %autoreload 2

# %%
from site import addsitepackages

addsitepackages(None)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from yggdrasil.data.etl.spark.init import get_spark_session
from yggdrasil.core.dtypes.dataset import TableSpec
from yggdrasil.core.dtypes.options import DatasetOptions, PreprocessingOptions
from yggdrasil.data.data_extractor.example import ExampleDataExtractor
from yggdrasil.data.datamodules.example import ExampleDataModule
# Out:
# INFO:yggdrasil.core.dataclasses:USE_VANILLA_DATACLASS: False
# INFO:yggdrasil.core.dataclasses:ARBITRARY_TYPES_ALLOWED: True
# INFO:datasets:PyTorch version 2.3.1 available.

# %%
example_datamodule = ExampleDataModule(
    input_table_spec=TableSpec(
        table_identifier="demo_processed",
        train_table_sample=80.0,
        eval_table_sample=10.0,
        test_table_sample=10.0,
    ),
    data_extractor=ExampleDataExtractor(),
    dataset_options=DatasetOptions(num_proc=10),
    features_preprocessing_options=PreprocessingOptions(nsamples=100),
)

# %%
example_datamodule.prepare_data()
example_datamodule.setup()
# Out:
# 25/06/18 15:36:57 WARN Utils: Your hostname, MacBook-Pro-Kasan.local resolves to a loopback address: 127.0.0.1; using 192.168.1.18 instead (on interface en0)
# 25/06/18 15:36:57 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/18 15:36:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 0
# INFO:yggdrasil.preprocessing.normalization:Feature 0 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.014374254271388054, max_value=0.9912529587745667)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 1
# INFO:yggdrasil.preprocessing.normalization:Feature 1 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.005124320741742849, max_value=0.9848589897155762)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 2
# INFO:yggdrasil.preprocessing.normalization:Feature 2 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0028454551938921213, max_value=0.9938046932220459)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 3
# INFO:yggdrasil.preprocessing.normalization:Feature 3 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.002592997858300805, max_value=0.9997247457504272)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 4
# INFO:yggdrasil.preprocessing.normalization:Feature 4 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.006982479710131884, max_value=0.9936391115188599)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 5
# INFO:yggdrasil.preprocessing.normalization:Feature 5 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.04991785064339638, max_value=0.9952793717384338)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 6
# INFO:yggdrasil.preprocessing.normalization:Feature 6 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0010783796897158027, max_value=0.959884762763977)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 7
# INFO:yggdrasil.preprocessing.normalization:Feature 7 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.009137090295553207, max_value=0.9965953230857849)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 8
# INFO:yggdrasil.preprocessing.normalization:Feature 8 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.007982312701642513, max_value=0.9966369271278381)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 9
# INFO:yggdrasil.preprocessing.normalization:Feature 9 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.005111902020871639, max_value=0.9833934307098389)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 10
# INFO:yggdrasil.preprocessing.normalization:Feature 10 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.007949663326144218, max_value=0.9915452599525452)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 11
# INFO:yggdrasil.preprocessing.normalization:Feature 11 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0039262110367417336, max_value=0.9932692646980286)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 12
# INFO:yggdrasil.preprocessing.normalization:Feature 12 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0030411991756409407, max_value=0.9924831986427307)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 13
# INFO:yggdrasil.preprocessing.normalization:Feature 13 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0006741597317159176, max_value=0.985746443271637)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 14
# INFO:yggdrasil.preprocessing.normalization:Feature 14 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0008845181437209249, max_value=0.992745578289032)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 15
# INFO:yggdrasil.preprocessing.normalization:Feature 15 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.011220316402614117, max_value=0.976691722869873)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 16
# INFO:yggdrasil.preprocessing.normalization:Feature 16 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.032220691442489624, max_value=0.9978883266448975)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 17
# INFO:yggdrasil.preprocessing.normalization:Feature 17 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.003587168175727129, max_value=0.995444118976593)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 18
# INFO:yggdrasil.preprocessing.normalization:Feature 18 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.014089720323681831, max_value=0.9986630082130432)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 19
# INFO:yggdrasil.preprocessing.normalization:Feature 19 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.003183558117598295, max_value=0.9931936860084534)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 20
# INFO:yggdrasil.preprocessing.normalization:Feature 20 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.002589941956102848, max_value=0.9971734881401062)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 21
# INFO:yggdrasil.preprocessing.normalization:Feature 21 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0012596450978890061, max_value=0.9670885801315308)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 22
# INFO:yggdrasil.preprocessing.normalization:Feature 22 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0016764258034527302, max_value=0.9932520389556885)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 23
# INFO:yggdrasil.preprocessing.normalization:Feature 23 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.031017865985631943, max_value=0.9922739267349243)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 24
# INFO:yggdrasil.preprocessing.normalization:Feature 24 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.02253505028784275, max_value=0.9878537058830261)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 25
# INFO:yggdrasil.preprocessing.normalization:Feature 25 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.022502107545733452, max_value=0.9884008169174194)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 26
# INFO:yggdrasil.preprocessing.normalization:Feature 26 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.010191150940954685, max_value=0.9492931365966797)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 27
# INFO:yggdrasil.preprocessing.normalization:Feature 27 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.020461905747652054, max_value=0.9982163906097412)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 28
# INFO:yggdrasil.preprocessing.normalization:Feature 28 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.021070176735520363, max_value=0.9795494079589844)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 29
# INFO:yggdrasil.preprocessing.normalization:Feature 29 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0034679612144827843, max_value=0.9986451864242554)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 30
# INFO:yggdrasil.preprocessing.normalization:Feature 30 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.023903105407953262, max_value=0.9969817399978638)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 31
# INFO:yggdrasil.preprocessing.normalization:Feature 31 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.020404091104865074, max_value=0.997133195400238)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 32
# INFO:yggdrasil.preprocessing.normalization:Feature 32 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.012973652221262455, max_value=0.9890304803848267)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 33
# INFO:yggdrasil.preprocessing.normalization:Feature 33 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.004541502334177494, max_value=0.9955714344978333)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 34
# INFO:yggdrasil.preprocessing.normalization:Feature 34 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0036681112833321095, max_value=0.9984805583953857)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 35
# INFO:yggdrasil.preprocessing.normalization:Feature 35 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.011233209632337093, max_value=0.9828271865844727)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 36
# INFO:yggdrasil.preprocessing.normalization:Feature 36 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0006547122611664236, max_value=0.986193060874939)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 37
# INFO:yggdrasil.preprocessing.normalization:Feature 37 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.002161243697628379, max_value=0.9928274750709534)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 38
# INFO:yggdrasil.preprocessing.normalization:Feature 38 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.008717578835785389, max_value=0.9874339699745178)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 39
# INFO:yggdrasil.preprocessing.normalization:Feature 39 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.008870968595147133, max_value=0.968523383140564)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 40
# INFO:yggdrasil.preprocessing.normalization:Feature 40 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0016196229262277484, max_value=0.9876602292060852)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 41
# INFO:yggdrasil.preprocessing.normalization:Feature 41 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.008750742301344872, max_value=0.9987192749977112)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 42
# INFO:yggdrasil.preprocessing.normalization:Feature 42 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.008699577301740646, max_value=0.9753044843673706)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 43
# INFO:yggdrasil.preprocessing.normalization:Feature 43 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.00629514642059803, max_value=0.9985373020172119)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 44
# INFO:yggdrasil.preprocessing.normalization:Feature 44 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0018097194842994213, max_value=0.9875466823577881)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 45
# INFO:yggdrasil.preprocessing.normalization:Feature 45 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.002803109586238861, max_value=0.9985027313232422)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 46
# INFO:yggdrasil.preprocessing.normalization:Feature 46 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0019692713394761086, max_value=0.9879330396652222)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 47
# INFO:yggdrasil.preprocessing.normalization:Feature 47 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.01585463620722294, max_value=0.9905595183372498)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 48
# INFO:yggdrasil.preprocessing.normalization:Feature 48 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.017916444689035416, max_value=0.99955815076828)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 49
# INFO:yggdrasil.preprocessing.normalization:Feature 49 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.014764421619474888, max_value=0.9839414358139038)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 50
# INFO:yggdrasil.preprocessing.normalization:Feature 50 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0014758796896785498, max_value=0.9986703395843506)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 51
# INFO:yggdrasil.preprocessing.normalization:Feature 51 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.002965763444080949, max_value=0.9985821843147278)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 52
# INFO:yggdrasil.preprocessing.normalization:Feature 52 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.013736199587583542, max_value=0.9721916913986206)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 53
# INFO:yggdrasil.preprocessing.normalization:Feature 53 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.02536487765610218, max_value=0.9924805760383606)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 54
# INFO:yggdrasil.preprocessing.normalization:Feature 54 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.010908123105764389, max_value=0.9980568885803223)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 55
# INFO:yggdrasil.preprocessing.normalization:Feature 55 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0010354819241911173, max_value=0.9910053014755249)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 56
# INFO:yggdrasil.preprocessing.normalization:Feature 56 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.011774844489991665, max_value=0.9984186887741089)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 57
# INFO:yggdrasil.preprocessing.normalization:Feature 57 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0012201853096485138, max_value=0.9975522756576538)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 58
# INFO:yggdrasil.preprocessing.normalization:Feature 58 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0010535434121266007, max_value=0.973449170589447)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 59
# INFO:yggdrasil.preprocessing.normalization:Feature 59 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.004809712991118431, max_value=0.9967221021652222)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 60
# INFO:yggdrasil.preprocessing.normalization:Feature 60 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.02904297038912773, max_value=0.9957420825958252)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 61
# INFO:yggdrasil.preprocessing.normalization:Feature 61 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.01685854233801365, max_value=0.9825705885887146)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 62
# INFO:yggdrasil.preprocessing.normalization:Feature 62 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.008430968970060349, max_value=0.9997328519821167)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 63
# INFO:yggdrasil.preprocessing.normalization:Feature 63 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.008756347000598907, max_value=0.9659706950187683)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 64
# INFO:yggdrasil.preprocessing.normalization:Feature 64 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0012335552601143718, max_value=0.9939001202583313)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 65
# INFO:yggdrasil.preprocessing.normalization:Feature 65 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.003098179353401065, max_value=0.9461888670921326)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 66
# INFO:yggdrasil.preprocessing.normalization:Feature 66 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.011130692437291145, max_value=0.9955289959907532)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 67
# INFO:yggdrasil.preprocessing.normalization:Feature 67 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.004220819100737572, max_value=0.9939354062080383)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 68
# INFO:yggdrasil.preprocessing.normalization:Feature 68 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.00025983716477639973, max_value=0.999529242515564)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 69
# INFO:yggdrasil.preprocessing.normalization:Feature 69 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.012383811175823212, max_value=0.9992385506629944)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 70
# INFO:yggdrasil.preprocessing.normalization:Feature 70 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.00636326102539897, max_value=0.9949458837509155)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 71
# INFO:yggdrasil.preprocessing.normalization:Feature 71 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.006076444406062365, max_value=0.9926331639289856)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 72
# INFO:yggdrasil.preprocessing.normalization:Feature 72 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.005358566530048847, max_value=0.9458631277084351)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 73
# INFO:yggdrasil.preprocessing.normalization:Feature 73 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.009276945143938065, max_value=0.9796305894851685)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 74
# INFO:yggdrasil.preprocessing.normalization:Feature 74 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.000734141212888062, max_value=0.9889049530029297)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 75
# INFO:yggdrasil.preprocessing.normalization:Feature 75 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.004096695221960545, max_value=0.9962479472160339)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 76
# INFO:yggdrasil.preprocessing.normalization:Feature 76 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.007977119646966457, max_value=0.9964062571525574)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 77
# INFO:yggdrasil.preprocessing.normalization:Feature 77 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.00863728392869234, max_value=0.9832118153572083)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 78
# INFO:yggdrasil.preprocessing.normalization:Feature 78 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.028688212856650352, max_value=0.9993159770965576)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 79
# INFO:yggdrasil.preprocessing.normalization:Feature 79 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.00777436001226306, max_value=0.9889296889305115)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 80
# INFO:yggdrasil.preprocessing.normalization:Feature 80 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.02698666974902153, max_value=0.9787331819534302)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 81
# INFO:yggdrasil.preprocessing.normalization:Feature 81 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.006450908724218607, max_value=0.9513726830482483)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 82
# INFO:yggdrasil.preprocessing.normalization:Feature 82 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.025895651429891586, max_value=0.994484543800354)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 83
# INFO:yggdrasil.preprocessing.normalization:Feature 83 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.00015720652299933136, max_value=0.989872395992279)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 84
# INFO:yggdrasil.preprocessing.normalization:Feature 84 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.012945536524057388, max_value=0.9508257508277893)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 85
# INFO:yggdrasil.preprocessing.normalization:Feature 85 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.014480562880635262, max_value=0.9885662794113159)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 86
# INFO:yggdrasil.preprocessing.normalization:Feature 86 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0033109537325799465, max_value=0.9952494502067566)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 87
# INFO:yggdrasil.preprocessing.normalization:Feature 87 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=2.688815766305197e-05, max_value=0.9942898154258728)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 88
# INFO:yggdrasil.preprocessing.normalization:Feature 88 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.00046584976371377707, max_value=0.9870781898498535)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 89
# INFO:yggdrasil.preprocessing.normalization:Feature 89 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.004376194439828396, max_value=0.9942122101783752)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 90
# INFO:yggdrasil.preprocessing.normalization:Feature 90 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.01785602793097496, max_value=0.9843931794166565)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 91
# INFO:yggdrasil.preprocessing.normalization:Feature 91 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.004898478277027607, max_value=0.9671064615249634)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 92
# INFO:yggdrasil.preprocessing.normalization:Feature 92 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.012971064075827599, max_value=0.9993798136711121)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 93
# INFO:yggdrasil.preprocessing.normalization:Feature 93 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.009663570672273636, max_value=0.9986578822135925)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 94
# INFO:yggdrasil.preprocessing.normalization:Feature 94 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.018230989575386047, max_value=0.9994549751281738)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 95
# INFO:yggdrasil.preprocessing.normalization:Feature 95 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.00406485004350543, max_value=0.9890903830528259)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 96
# INFO:yggdrasil.preprocessing.normalization:Feature 96 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0077625238336622715, max_value=0.9814802408218384)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 97
# INFO:yggdrasil.preprocessing.normalization:Feature 97 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.023683106526732445, max_value=0.9977007508277893)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 98
# INFO:yggdrasil.preprocessing.normalization:Feature 98 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.008690932765603065, max_value=0.9853715896606445)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 99
# INFO:yggdrasil.preprocessing.normalization:Feature 99 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.01489114947617054, max_value=0.9906436204910278)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 100
# INFO:yggdrasil.preprocessing.normalization:Feature 100 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.009121011942625046, max_value=0.9932973980903625)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 101
# INFO:yggdrasil.preprocessing.normalization:Feature 101 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.010577854700386524, max_value=0.98717200756073)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 102
# INFO:yggdrasil.preprocessing.normalization:Feature 102 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.05604270100593567, max_value=0.9966809153556824)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 103
# INFO:yggdrasil.preprocessing.normalization:Feature 103 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0062984502874314785, max_value=0.9927525520324707)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 104
# INFO:yggdrasil.preprocessing.normalization:Feature 104 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.00011525556328706443, max_value=0.9910762906074524)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 105
# INFO:yggdrasil.preprocessing.normalization:Feature 105 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.008072334341704845, max_value=0.9917594790458679)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 106
# INFO:yggdrasil.preprocessing.normalization:Feature 106 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.039694253355264664, max_value=0.9916270971298218)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 107
# INFO:yggdrasil.preprocessing.normalization:Feature 107 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.005451723001897335, max_value=0.9584749341011047)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 108
# INFO:yggdrasil.preprocessing.normalization:Feature 108 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.02651100978255272, max_value=0.9925829768180847)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 109
# INFO:yggdrasil.preprocessing.normalization:Feature 109 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.016695445403456688, max_value=0.984178900718689)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 110
# INFO:yggdrasil.preprocessing.normalization:Feature 110 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0019709591288119555, max_value=0.999005913734436)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 111
# INFO:yggdrasil.preprocessing.normalization:Feature 111 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.00011218474537599832, max_value=0.9990670084953308)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 112
# INFO:yggdrasil.preprocessing.normalization:Feature 112 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.020310118794441223, max_value=0.9900383949279785)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 113
# INFO:yggdrasil.preprocessing.normalization:Feature 113 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.01247946172952652, max_value=0.9981111884117126)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 114
# INFO:yggdrasil.preprocessing.normalization:Feature 114 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.018322335556149483, max_value=0.948999285697937)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 115
# INFO:yggdrasil.preprocessing.normalization:Feature 115 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.02907162345945835, max_value=0.9875141978263855)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 116
# INFO:yggdrasil.preprocessing.normalization:Feature 116 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0033788231667131186, max_value=0.9973315596580505)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 117
# INFO:yggdrasil.preprocessing.normalization:Feature 117 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=3.969874160247855e-05, max_value=0.993898868560791)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 118
# INFO:yggdrasil.preprocessing.normalization:Feature 118 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.0015834069345146418, max_value=0.9967969059944153)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 119
# INFO:yggdrasil.preprocessing.normalization:Feature 119 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.005370812956243753, max_value=0.9837448000907898)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 120
# INFO:yggdrasil.preprocessing.normalization:Feature 120 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.018775014206767082, max_value=0.9940340518951416)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 121
# INFO:yggdrasil.preprocessing.normalization:Feature 121 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.00988281425088644, max_value=0.985414445400238)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 122
# INFO:yggdrasil.preprocessing.normalization:Feature 122 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.029102591797709465, max_value=0.9988043904304504)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 123
# INFO:yggdrasil.preprocessing.normalization:Feature 123 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.02423698455095291, max_value=0.9994209408760071)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 124
# INFO:yggdrasil.preprocessing.normalization:Feature 124 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.003481587627902627, max_value=0.989874541759491)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 125
# INFO:yggdrasil.preprocessing.normalization:Feature 125 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.015574900433421135, max_value=0.9968510866165161)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 126
# INFO:yggdrasil.preprocessing.normalization:Feature 126 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.002617287216708064, max_value=0.994167685508728)
# INFO:yggdrasil.preprocessing.normalization:Extracting normalization for feature: 127
# INFO:yggdrasil.preprocessing.normalization:Feature 127 normalization NormalizationParams(ftype=<Ftype.PROBABILITY: 'probability'>, boxcox_lambda=None, boxcox_shift=0.0, mean=0.0, stdev=1.0, possible_values=None, quantiles=None, min_value=0.002916395664215088, max_value=0.9848762154579163)

# %%
next(iter(example_datamodule.train_dataloader())).size()

# %%
assert example_datamodule.train_data is not None
assert example_datamodule.eval_data is not None
assert example_datamodule.test_data is not None

print(example_datamodule.train_data)
print(example_datamodule.eval_data)
print(example_datamodule.test_data)
# Out:
# ParquetDataset(dataset_url='file:///Users/juicefv/project_template/notebooks/example/spark-warehouse/tmp_parquet_meugplsupe')
# ParquetDataset(dataset_url='file:///Users/juicefv/project_template/notebooks/example/spark-warehouse/tmp_parquet_wywfirmgci')
# ParquetDataset(dataset_url='file:///Users/juicefv/project_template/notebooks/example/spark-warehouse/tmp_parquet_zffecyztwk')

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 6))

assert example_datamodule.train_data is not None
assert example_datamodule.eval_data is not None
assert example_datamodule.test_data is not None

train_target = pd.read_parquet(example_datamodule.train_data.dataset_url, columns=["target"])
eval_target = pd.read_parquet(example_datamodule.eval_data.dataset_url, columns=["target"])
test_target = pd.read_parquet(example_datamodule.test_data.dataset_url, columns=["target"])
sns.histplot(train_target, x="target", bins=2, stat="probability", ax=ax[0])
ax[0].set_title("Train Data")
sns.histplot(eval_target, x="target", bins=2, stat="probability", ax=ax[1])
ax[1].set_title("Eval Data")
sns.histplot(test_target, x="target", bins=2, stat="probability", ax=ax[2])
ax[2].set_title("Test Data")
plt.tight_layout()

# %%
assert example_datamodule.train_data is not None
assert example_datamodule.eval_data is not None
assert example_datamodule.test_data is not None

spark = get_spark_session()
spark.sql(f"DROP TABLE IF EXISTS {example_datamodule.train_data.dataset_url.split('/')[-1]}")
spark.sql(f"DROP TABLE IF EXISTS {example_datamodule.eval_data.dataset_url.split('/')[-1]}")
spark.sql(f"DROP TABLE IF EXISTS {example_datamodule.test_data.dataset_url.split('/')[-1]}")
